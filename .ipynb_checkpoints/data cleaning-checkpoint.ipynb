# %%
import pandas as pd
import csv

# %%
# Read CSV
df = pd.read_csv('CountryCleanedMET.csv')
df
# Out:
# C:\Users\pahou\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (3,5,17,23,24,25,26,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                   Object Number  Is Public Domain  Object ID Gallery Number  \
# 0                    1976.246.1             False     503079            NaN
# 1                    1976.246.2             False     503080            NaN
# 2                1976.246.3a, b             False     503081            NaN
# 3                    1976.246.4             False     503082            NaN
# 4                 Inst.1977.1.1             False     503162            NaN
# ...                         ...               ...        ...            ...
# 204831            2019.597.2.29             False     848690            NaN
# 204832                 2020.293             False     848693            NaN
# ...

# %%
print(df.columns.values)
# Out:
# ['Object Number' 'Is Public Domain' 'Object ID' 'Gallery Number'
#  'Department' 'AccessionYear' 'Object Name' 'Title' 'Culture' 'Reign'
#  'Portfolio' 'Constiuent ID' 'Artist Role' 'Artist Prefix'
#  'Artist Display Name' 'Artist Display Bio' 'Artist Suffix'
#  'Artist Nationality' 'Object Begin Date' 'Object End Date' 'Medium'
#  'Dimensions' 'Credit Line' 'Geography Type' 'City' 'State' 'County'
#  'Country' 'Classification']

# %%
clean_df = df[["Object Number","Object ID", "Department", "AccessionYear", "Object Name", "Culture", "Artist Display Name", 
              "Artist Nationality","Object Begin Date", "Object End Date", "Credit Line", "Country", "Classification"]]

# %%
clean_df
# Out:
#                   Object Number  Object ID  \
# 0                    1976.246.1     503079
# 1                    1976.246.2     503080
# 2                1976.246.3a, b     503081
# 3                    1976.246.4     503082
# 4                 Inst.1977.1.1     503162
# ...                         ...        ...
# 204831            2019.597.2.29     848690
# 204832                 2020.293     848693
# 204833             1974.356.128     848709
# 204834  07.225.464d MODERN COPY     849461
# 204835  07.225.464c MODERN COPY     849462
#
#                                     Department AccessionYear    Object Name  \
# 0                          Musical Instruments          1976          Rubab
# 1                          Musical Instruments          1976          Rubab
# 2                          Musical Instruments          1976        Dilruba
# 3                          Musical Instruments          1976   Kunari Sitar
# ...

# %%
new_df=clean_df[clean_df['Culture'].str.contains("China")]
new_df.reset_index(drop=True)
# Out:
#       Object Number  Object ID         Department AccessionYear  \
# 0          13.31.15       7411  The American Wing          1913
# 1        33.120.164       7457  The American Wing          1933
# 2          2001.632      24976     Arms and Armor          2001
# 3           1999.26      26633     Arms and Armor          1999
# 4        96.14.1896      35967          Asian Art          1896
# ...             ...        ...                ...           ...
# 13939      2020.332     843762          Asian Art          2020
# 13940   2020.333a–d     843763          Asian Art          2020
# 13941      2020.334     843764          Asian Art          2020
# 13942  2020.335a, b     843765          Asian Art          2020
# 13943      2020.356     844397          Asian Art          2020
#
#                                     Object Name  \
# 0                                   Shaving mug
# 1                                        Buckle
# 2      Element from a lacquered leather cuirass
# ...

# %%
new_df.to_csv ('new_data.csv', index = None, header=True)
